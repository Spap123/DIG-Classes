# %%
import numpy as np 
import pandas as pd

# %%
#pandas series
#pandas dataframe

# %%
"""""
pen 100
shirt 200
book 300
mouse 400
"""
# Out:
# '""\npen 100\nshirt 200\nbook 300\nmouse 400\n'

# %%
pricelist = [100,200,300,400]
productseries = pd.Series(pricelist,index=['pen','shirt','book','mouse'])

# %%
print(productseries)
# Out:
# pen      100
# shirt    200
# book     300
# mouse    400
# dtype: int64

# %%
productdf = pd.DataFrame([[100,200,300,400],[450,220,350,410]],columns=['pen','shirt','book','mouse'])

# %%
productdf
# Out:
#    pen  shirt  book  mouse
# 0  100    200   300    400
# 1  450    220   350    410

# %%
#size 
productdf.size
# Out:
# 8

# %%
#shape
productdf.shape
# Out:
# (2, 4)

# %%
productrows = pd.DataFrame([[150,290,310,440],[850,920,150,480]],columns=['pen','shirt','book','mouse'])

# %%
productrows
# Out:
#    pen  shirt  book  mouse
# 0  150    290   310    440
# 1  850    920   150    480

# %%
#append 
productdf = productdf.append(productrows)
# Out:
# C:\Users\sengu\AppData\Local\Temp\ipykernel_23472\1760151354.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   productdf = productdf.append(productrows)

# %%
productdf
# Out:
#    pen  shirt  book  mouse
# 0  100    200   300    400
# 1  450    220   350    410
# 0  150    290   310    440
# 1  850    920   150    480

# %%
#reset index
productdf.reset_index(inplace=True)

# %%
productdf
# Out:
#    index  pen  shirt  book  mouse
# 0      0  100    200   300    400
# 1      1  450    220   350    410
# 2      0  150    290   310    440
# 3      1  850    920   150    480

# %%
productdf['pencil'] = [560,780,150,630]

# %%
productdf
# Out:
#    index  pen  shirt  book  mouse  pencil
# 0      0  100    200   300    400     560
# 1      1  450    220   350    410     780
# 2      0  150    290   310    440     150
# 3      1  850    920   150    480     630

# %%
productdf.shape
# Out:
# (4, 6)

# %%
productdf.size
# Out:
# 24

# %%
productdf = productdf.drop(columns='index')

# %%
productdf
# Out:
#    pen  shirt  book  mouse  pencil
# 0  100    200   300    400     560
# 1  450    220   350    410     780
# 2  150    290   310    440     150
# 3  850    920   150    480     630

# %%
productdf = productdf.drop(index=[0])

# %%
productdf
# Out:
#    pen  shirt  book  mouse  pencil
# 1  450    220   350    410     780
# 2  150    290   310    440     150
# 3  850    920   150    480     630

# %%
productdf = productdf.drop(index=[2])
productdf
# Out:
#    pen  shirt  book  mouse  pencil
# 1  450    220   350    410     780
# 3  850    920   150    480     630

# %%
productdf.reset_index(inplace=True)

# %%
productdf
# Out:
#    index  pen  shirt  book  mouse  pencil
# 0      1  450    220   350    410     780
# 1      3  850    920   150    480     630

# %%
productdf1 = pd.DataFrame([[100,200,300,400],[450,220,350,410]],columns=['pen','shirt','book','mouse'])
productrows = pd.DataFrame([[150,290,310,440],[850,920,150,480]],columns=['pen','shirt','book','mouse'])
productdf1 = productdf1.append(productrows)
# Out:
# C:\Users\sengu\AppData\Local\Temp\ipykernel_23472\836202204.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   productdf1 = productdf1.append(productrows)

# %%
productdf1
# Out:
#    pen  shirt  book  mouse
# 0  100    200   300    400
# 1  450    220   350    410
# 0  150    290   310    440
# 1  850    920   150    480

# %%
productdf1.reset_index(inplace=True)

# %%
productdf1.index = pd.RangeIndex(start=1,stop=5,step=1)

# %%
productdf1
# Out:
#    index  pen  shirt  book  mouse
# 1      0  100    200   300    400
# 2      1  450    220   350    410
# 3      0  150    290   310    440
# 4      1  850    920   150    480

# %%
productdf1 = productdf1.drop(columns='index')

# %%
productdf1
# Out:
#    pen  shirt  book  mouse
# 1  100    200   300    400
# 2  450    220   350    410
# 3  150    290   310    440
# 4  850    920   150    480

# %%
df = pd.read_csv(r'D:\DS WorkFlow\Data Is Good Class Files\Batches\2023-Classes\16th July Batch\diabetes.csv')

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
print(df[['Glucose']].describe())
# Out:
#           Glucose
# count  768.000000
# mean   120.894531
# std     31.972618
# min      0.000000
# 25%     99.000000
# 50%    117.000000
# 75%    140.250000
# max    199.000000

# %%
ilpd = pd.read_csv(r'D:\DS WorkFlow\Data Is Good Class Files\Batches\2023-Classes\25th Feb Batch\ILPD.csv')

# %%
ilpd1 = pd.read_csv('ILPD.csv')

# %%
ilpd.head()
# Out:
#    Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  Liverpatient
# 0   65  Female   0.7  0.1      187    16    18  6.8  3.3  0.90             1
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1

# %%
ilpd1.head()
# Out:
#    Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  Liverpatient
# 0   65  Female   0.7  0.1      187    16    18  6.8  3.3  0.90             1
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1

# %%
ilpd.describe()
# Out:
#               Age          TB          DB      Alkphos         Sgpt  \
# count  583.000000  583.000000  583.000000   583.000000   583.000000
# mean    44.746141    3.298799    1.486106   290.576329    80.713551
# std     16.189833    6.209522    2.808498   242.937989   182.620356
# min      4.000000    0.400000    0.100000    63.000000    10.000000
# 25%     33.000000    0.800000    0.200000   175.500000    23.000000
# 50%     45.000000    1.000000    0.300000   208.000000    35.000000
# 75%     58.000000    2.600000    1.300000   298.000000    60.500000
# max     90.000000   75.000000   19.700000  2110.000000  2000.000000
#
#               Sgot          TP         ALB          AG  Liverpatient
# count   583.000000  583.000000  583.000000  579.000000    583.000000
# mean    109.910806    6.483190    3.141852    0.947064      1.286449
# std     288.918529    1.085451    0.795519    0.319592      0.452490
# min      10.000000    2.700000    0.900000    0.300000      1.000000
# ...

# %%
ilpd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Age           583 non-null    int64
#  1   Gender        583 non-null    object
#  2   TB            583 non-null    float64
#  3   DB            583 non-null    float64
#  4   Alkphos       583 non-null    int64
#  5   Sgpt          583 non-null    int64
#  6   Sgot          583 non-null    int64
#  7   TP            583 non-null    float64
#  8   ALB           583 non-null    float64
#  9   AG            579 non-null    float64
#  10  Liverpatient  583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
ilpd.isnull().sum()
# Out:
# Age             0
# Gender          0
# TB              0
# DB              0
# Alkphos         0
# Sgpt            0
# Sgot            0
# TP              0
# ALB             0
# AG              4
# Liverpatient    0
# dtype: int64

# %%
ilpd.head()
# Out:
#    Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  Liverpatient
# 0   65  Female   0.7  0.1      187    16    18  6.8  3.3  0.90             1
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1

# %%
ilpd.sort_values(by='TB',ascending=False).head(8)
# Out:
#      Age  Gender    TB    DB  Alkphos  Sgpt  Sgot   TP  ALB   AG  Liverpatient
# 166   55    Male  75.0   3.6      332    40    66  6.2  2.5  0.6             1
# 559   26    Male  42.8  19.7      390    75   138  7.5  2.6  0.5             1
# 505   32    Male  32.6  14.1      219    95   235  5.8  3.1  1.1             1
# 531   40    Male  30.8  18.3      285   110   186  7.9  2.7  0.5             1
# 259   42    Male  30.5  14.2      285    65   130  5.2  2.1  0.6             1
# 504   32    Male  30.5  17.1      218    39    79  5.5  2.7  0.9             1
# 547   50  Female  27.7  10.8      380    39   348  7.1  2.3  0.4             1
# 199    7  Female  27.2  11.8     1420   790  1050  6.1  2.0  0.4             1

# %%
male_ilpd = ilpd[ilpd['Gender']=="Male"]
female_ilpd = ilpd[ilpd['Gender']=="Female"]

# %%
male_ilpd.head()
# Out:
#    Age Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  Liverpatient
# 1   62   Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2   62   Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3   58   Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4   72   Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# 5   46   Male   1.8  0.7      208    19    14  7.6  4.4  1.30             1

# %%
male_ilpd.describe()
# Out:
#               Age          TB          DB      Alkphos         Sgpt  \
# count  441.000000  441.000000  441.000000   441.000000   441.000000
# mean    45.265306    3.613152    1.646032   286.789116    89.238095
# std     16.266108    6.558631    2.912807   221.591533   202.438273
# min      4.000000    0.400000    0.100000    75.000000    10.000000
# 25%     33.000000    0.800000    0.200000   179.000000    25.000000
# 50%     45.000000    1.200000    0.400000   215.000000    38.000000
# 75%     60.000000    2.900000    1.500000   298.000000    65.000000
# max     90.000000   75.000000   19.700000  2110.000000  2000.000000
#
#               Sgot          TP         ALB          AG  Liverpatient
# count   441.000000  441.000000  441.000000  439.000000    441.000000
# mean    123.070295    6.428345    3.099546    0.946446      1.265306
# std     323.216916    1.064762    0.780967    0.329313      0.441997
# min      11.000000    2.700000    0.900000    0.300000      1.000000
# ...

# %%
female_ilpd.describe()
# Out:
#               Age          TB          DB      Alkphos        Sgpt  \
# count  142.000000  142.000000  142.000000   142.000000  142.000000
# mean    43.133803    2.322535    0.989437   302.338028   54.239437
# std     15.899163    4.863417    2.398513   300.328139   94.023155
# min      7.000000    0.500000    0.100000    63.000000   10.000000
# 25%     31.000000    0.700000    0.200000   165.000000   20.000000
# 50%     45.000000    0.800000    0.200000   194.500000   26.000000
# 75%     53.000000    1.100000    0.400000   293.000000   46.750000
# max     85.000000   27.700000   12.800000  1896.000000  790.000000
#
#               Sgot          TP         ALB          AG  Liverpatient
# count   142.000000  142.000000  142.000000  140.000000    142.000000
# mean     69.042254    6.653521    3.273239    0.949000      1.352113
# std     127.769733    1.134355    0.828218    0.288083      0.479320
# min      10.000000    3.600000    1.000000    0.300000      1.000000
# ...

# %%
female_ilpd.isnull().sum()
# Out:
# Age             0
# Gender          0
# TB              0
# DB              0
# Alkphos         0
# Sgpt            0
# Sgot            0
# TP              0
# ALB             0
# AG              2
# Liverpatient    0
# dtype: int64

# %%
male_ilpd['Age'].describe()
# Out:
# count    441.000000
# mean      45.265306
# std       16.266108
# min        4.000000
# 25%       33.000000
# 50%       45.000000
# 75%       60.000000
# max       90.000000
# Name: Age, dtype: float64

# %%
age_more_50_male = male_ilpd[male_ilpd['Age']>50]

# %%
age_more_50_male.head()
# Out:
#    Age Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  Liverpatient
# 1   62   Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2   62   Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3   58   Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4   72   Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# 9   55   Male   0.7  0.2      290    53    58  6.8  3.4  1.00             1

# %%
age_more_50_male.describe()
# Out:
#              Age          TB          DB      Alkphos         Sgpt  \
# count  168.00000  168.000000  168.000000   168.000000   168.000000
# mean    62.10119    3.607143    1.532143   310.428571    65.500000
# std      7.22242    7.065837    2.371369   240.760436   115.598158
# min     51.00000    0.400000    0.100000    97.000000    12.000000
# 25%     57.00000    0.800000    0.200000   180.000000    24.000000
# 50%     60.00000    1.300000    0.500000   216.500000    36.500000
# 75%     66.00000    3.025000    1.525000   315.000000    59.250000
# max     90.00000   75.000000   12.600000  1750.000000  1250.000000
#
#               Sgot          TP         ALB         AG  Liverpatient
# count   168.000000  168.000000  168.000000  167.00000    168.000000
# mean    117.113095    6.188095    2.851786    0.86497      1.208333
# std     395.775861    1.006018    0.720942    0.31873      0.407331
# min      14.000000    2.700000    0.900000    0.35000      1.000000
# ...

# %%
ilpd.describe()
# Out:
#               Age          TB          DB      Alkphos         Sgpt  \
# count  583.000000  583.000000  583.000000   583.000000   583.000000
# mean    44.746141    3.298799    1.486106   290.576329    80.713551
# std     16.189833    6.209522    2.808498   242.937989   182.620356
# min      4.000000    0.400000    0.100000    63.000000    10.000000
# 25%     33.000000    0.800000    0.200000   175.500000    23.000000
# 50%     45.000000    1.000000    0.300000   208.000000    35.000000
# 75%     58.000000    2.600000    1.300000   298.000000    60.500000
# max     90.000000   75.000000   19.700000  2110.000000  2000.000000
#
#               Sgot          TP         ALB          AG  Liverpatient
# count   583.000000  583.000000  583.000000  579.000000    583.000000
# mean    109.910806    6.483190    3.141852    0.947064      1.286449
# std     288.918529    1.085451    0.795519    0.319592      0.452490
# min      10.000000    2.700000    0.900000    0.300000      1.000000
# ...

# %%
male_more_50 = ilpd[(ilpd['Gender']=='Male') & (ilpd['Age']>50)]

# %%
male_more_50.describe()
# Out:
#              Age          TB          DB      Alkphos         Sgpt  \
# count  168.00000  168.000000  168.000000   168.000000   168.000000
# mean    62.10119    3.607143    1.532143   310.428571    65.500000
# std      7.22242    7.065837    2.371369   240.760436   115.598158
# min     51.00000    0.400000    0.100000    97.000000    12.000000
# 25%     57.00000    0.800000    0.200000   180.000000    24.000000
# 50%     60.00000    1.300000    0.500000   216.500000    36.500000
# 75%     66.00000    3.025000    1.525000   315.000000    59.250000
# max     90.00000   75.000000   12.600000  1750.000000  1250.000000
#
#               Sgot          TP         ALB         AG  Liverpatient
# count   168.000000  168.000000  168.000000  167.00000    168.000000
# mean    117.113095    6.188095    2.851786    0.86497      1.208333
# std     395.775861    1.006018    0.720942    0.31873      0.407331
# min      14.000000    2.700000    0.900000    0.35000      1.000000
# ...

# %%
male_more_50['Gender'].describe()
# Out:
# count      168
# unique       1
# top       Male
# freq       168
# Name: Gender, dtype: object

# %%
ilpd['Gender'].describe()
# Out:
# count      583
# unique       2
# top       Male
# freq       441
# Name: Gender, dtype: object

# %%
ilpd.describe()
# Out:
#               Age          TB          DB      Alkphos         Sgpt  \
# count  583.000000  583.000000  583.000000   583.000000   583.000000
# mean    44.746141    3.298799    1.486106   290.576329    80.713551
# std     16.189833    6.209522    2.808498   242.937989   182.620356
# min      4.000000    0.400000    0.100000    63.000000    10.000000
# 25%     33.000000    0.800000    0.200000   175.500000    23.000000
# 50%     45.000000    1.000000    0.300000   208.000000    35.000000
# 75%     58.000000    2.600000    1.300000   298.000000    60.500000
# max     90.000000   75.000000   19.700000  2110.000000  2000.000000
#
#               Sgot          TP         ALB          AG  Liverpatient
# count   583.000000  583.000000  583.000000  579.000000    583.000000
# mean    109.910806    6.483190    3.141852    0.947064      1.286449
# std     288.918529    1.085451    0.795519    0.319592      0.452490
# min      10.000000    2.700000    0.900000    0.300000      1.000000
# ...

# %%
and_logic = ilpd[(ilpd['Gender']=="Female") & (ilpd['Age']>50)]
or_logic = ilpd[(ilpd['Gender']=="Female") | (ilpd['Age']>50)]

# %%
and_logic.describe()
# Out:
#              Age         TB         DB      Alkphos       Sgpt        Sgot  \
# count  39.000000  39.000000  39.000000    39.000000  39.000000   39.000000
# mean   62.512821   2.782051   1.271795   389.564103  32.205128   39.410256
# std     8.887815   5.198931   2.757473   436.287676  21.125165   30.597315
# min    51.000000   0.600000   0.100000   130.000000  10.000000   12.000000
# 25%    55.000000   0.700000   0.200000   180.000000  18.000000   19.500000
# 50%    60.000000   0.800000   0.200000   202.000000  24.000000   29.000000
# 75%    68.000000   1.550000   0.750000   315.000000  42.500000   46.000000
# max    85.000000  23.200000  12.600000  1896.000000  96.000000  142.000000
#
#               TP        ALB         AG  Liverpatient
# count  39.000000  39.000000  39.000000     39.000000
# mean    6.476923   3.087179   0.890769      1.358974
# std     1.114371   0.793453   0.261960      0.485971
# min     4.400000   1.600000   0.400000      1.000000
# ...

# %%
or_logic.describe()
# Out:
#               Age          TB          DB      Alkphos         Sgpt  \
# count  310.000000  310.000000  310.000000   310.000000   310.000000
# mean    53.412903    3.018710    1.283548   306.722581    60.341935
# std     15.268805    6.179539    2.395334   269.261643   106.242955
# min      7.000000    0.400000    0.100000    63.000000    10.000000
# 25%     45.000000    0.800000    0.200000   174.250000    21.000000
# 50%     56.000000    0.900000    0.300000   204.500000    31.000000
# 75%     64.000000    2.275000    1.100000   305.500000    53.000000
# max     90.000000   75.000000   12.800000  1896.000000  1250.000000
#
#               Sgot          TP         ALB          AG  Liverpatient
# count   310.000000  310.000000  310.000000  307.000000    310.000000
# mean     95.093548    6.401290    3.044839    0.903290      1.274194
# std     304.434870    1.089995    0.798840    0.307517      0.446828
# min      10.000000    2.700000    0.900000    0.300000      1.000000
# ...

# %%
and_or_logic = ilpd[((ilpd['Liverpatient']==1) & (ilpd['Age']>50)) & (ilpd['TP']>2) ]

# %%
and_or_logic.describe()
# Out:
#               Age          TB          DB      Alkphos         Sgpt  \
# count  158.000000  158.000000  158.000000   158.000000   158.000000
# mean    62.208861    4.222785    1.844304   364.088608    68.696203
# std      7.788652    7.563842    2.695301   318.238611   118.775639
# min     51.000000    0.400000    0.100000    97.000000    13.000000
# 25%     55.000000    0.800000    0.200000   189.250000    24.000000
# 50%     60.000000    1.700000    0.650000   238.000000    39.500000
# 75%     68.000000    4.150000    2.250000   383.250000    62.000000
# max     90.000000   75.000000   12.600000  1896.000000  1250.000000
#
#               Sgot          TP         ALB          AG  Liverpatient
# count   158.000000  158.000000  158.000000  157.000000         158.0
# mean    123.443038    6.213924    2.792405    0.814459           1.0
# std     407.403656    1.032002    0.715750    0.287309           0.0
# min      14.000000    2.700000    0.900000    0.350000           1.0
# ...

# %%
ilpd.plot.scatter('TB','DB')
# Out:
# <AxesSubplot:xlabel='TB', ylabel='DB'>

# %%
ilpd.hist(column='Age',by = 'Gender')
# Out:
# array([<AxesSubplot:title={'center':'Female'}>,
#        <AxesSubplot:title={'center':'Male'}>], dtype=object)

# %%
data = ilpd.iloc[1:10,]

# %%
data
# Out:
#    Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  Liverpatient
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# 5   46    Male   1.8  0.7      208    19    14  7.6  4.4  1.30             1
# 6   26  Female   0.9  0.2      154    16    12  7.0  3.5  1.00             1
# 7   29  Female   0.9  0.3      202    14    11  6.7  3.6  1.10             1
# 8   17    Male   0.9  0.3      202    22    19  7.4  4.1  1.20             2
# 9   55    Male   0.7  0.2      290    53    58  6.8  3.4  1.00             1

# %%
ilpd['Liverpatient'].plot.pie()
# Out:
# <AxesSubplot:ylabel='Liverpatient'>

# %%
data.head()
# Out:
#    Age Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  Liverpatient
# 1   62   Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2   62   Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3   58   Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4   72   Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# 5   46   Male   1.8  0.7      208    19    14  7.6  4.4  1.30             1

# %%
#displaying a single column of a single row
print(data.iloc[4,2])
# Out:
# 1.8

# %%
#displaying all the records of a specific row
print(data.iloc[3])
# Out:
# Age               72
# Gender          Male
# TB               3.9
# DB               2.0
# Alkphos          195
# Sgpt              27
# Sgot              59
# TP               7.3
# ALB              2.4
# AG               0.4
# Liverpatient       1
# Name: 4, dtype: object

# %%
print(data.iloc[[4,2],[1,3]])
# Out:
#   Gender   DB
# 5   Male  0.7
# 3   Male  0.4

# %%
print(data.iloc[0:3,1:4])
# Out:
#   Gender    TB   DB
# 1   Male  10.9  5.5
# 2   Male   7.3  4.1
# 3   Male   1.0  0.4

# %%
#loc method
print(data.loc[2:5])
# Out:
#    Age Gender   TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  Liverpatient
# 2   62   Male  7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3   58   Male  1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4   72   Male  3.9  2.0      195    27    59  7.3  2.4  0.40             1
# 5   46   Male  1.8  0.7      208    19    14  7.6  4.4  1.30             1

# %%
data.head()
# Out:
#    Age Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  Liverpatient
# 1   62   Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2   62   Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3   58   Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4   72   Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# 5   46   Male   1.8  0.7      208    19    14  7.6  4.4  1.30             1

# %%
print(data.iloc[[4,2],[1,3]])
# Out:
#   Gender   DB
# 5   Male  0.7
# 3   Male  0.4

# %%
print(data.loc[[4,5],['Gender','DB']])
# Out:
#   Gender   DB
# 4   Male  2.0
# 5   Male  0.7

# %%
print(data.loc[1:5,'Gender':'AG'])
# Out:
#   Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG
# 1   Male  10.9  5.5      699    64   100  7.5  3.2  0.74
# 2   Male   7.3  4.1      490    60    68  7.0  3.3  0.89
# 3   Male   1.0  0.4      182    14    20  6.8  3.4  1.00
# 4   Male   3.9  2.0      195    27    59  7.3  2.4  0.40
# 5   Male   1.8  0.7      208    19    14  7.6  4.4  1.30

# %%
print(data.loc[data['DB']==2,'Age':'TB'])
# Out:
#    Age Gender   TB
# 4   72   Male  3.9

# %%
print(data.loc[data['Age']>40,'Age':'DB'])
# Out:
#    Age Gender    TB   DB
# 1   62   Male  10.9  5.5
# 2   62   Male   7.3  4.1
# 3   58   Male   1.0  0.4
# 4   72   Male   3.9  2.0
# 5   46   Male   1.8  0.7
# 9   55   Male   0.7  0.2

# %%
print(data.loc[(data['Age']>40) | (data['Sgpt']>60),['Age','DB']])
# Out:
#    Age   DB
# 1   62  5.5
# 2   62  4.1
# 3   58  0.4
# 4   72  2.0
# 5   46  0.7
# 9   55  0.2

# %%
print(data.groupby(data['Gender']).count())
# Out:
#         Age  TB  DB  Alkphos  Sgpt  Sgot  TP  ALB  AG  Liverpatient
# Gender
# Female    2   2   2        2     2     2   2    2   2             2
# Male      7   7   7        7     7     7   7    7   7             7

# %%
print(data['DB'].groupby([data['Liverpatient']]).min())
# Out:
# Liverpatient
# 1    0.2
# 2    0.3
# Name: DB, dtype: float64

# %%
data.head()
# Out:
#    Age Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  Liverpatient
# 1   62   Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2   62   Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3   58   Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4   72   Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# 5   46   Male   1.8  0.7      208    19    14  7.6  4.4  1.30             1
