# %%
print("Hello World")
# Out:
# Hello World

# %%
a_b = 25
print(a_b)
# Out:
# 25

# %%
var1 = "Hello" #string or denoted as str
var2 = 152 #integer or denoted as int
var3 = 14.5 #floating point number or denoted as float

# %%
print(var3)
# Out:
# 14.5

# %%
print(type(var3))
# Out:
# <class 'float'>

# %%
var4 = 5
var5 = "park"
var6 = var4*var5
print(var6)
# Out:
# parkparkparkparkpark

# %%
var8 = "park"
var9 = 5
print(var9+float(var8))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\DS WorkFlow\Data Is Good Class Files\Batches\2023-Classes\19th Nov Batch\Class 12.03.2023 -python introduction.ipynb Cell 7 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/DS%20WorkFlow/Data%20Is%20Good%20Class%20Files/Batches/2023-Classes/19th%20Nov%20Batch/Class%2012.03.2023%20-python%20introduction.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> var8 = "park"
#       <a href='vscode-notebook-cell:/d%3A/DS%20WorkFlow/Data%20Is%20Good%20Class%20Files/Batches/2023-Classes/19th%20Nov%20Batch/Class%2012.03.2023%20-python%20introduction.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> var9 = 5
# ----> <a href='vscode-notebook-cell:/d%3A/DS%20WorkFlow/Data%20Is%20Good%20Class%20Files/Batches/2023-Classes/19th%20Nov%20Batch/Class%2012.03.2023%20-python%20introduction.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> print(var9+float(var8))
#
# ValueError: could not convert string to float: 'park'

# %%
var10 = "5"
var11 = "2"
var12 = "Hello"
var13 = (int(var10)-int(var11))*var12

# %%
print(var13)
# Out:
# HelloHelloHello

# %%
print(3*"park\n")
# Out:
# park
# park
# park

# %%
var1 = "harry potter"
var2 = "maguire"
print(var1+" "+var2)
# Out:
# harry potter maguire

# %%
print(len(var1))
# Out:
# 12

# %%
a=b=c=10

# %%
print(b)
# Out:
# 10

# %%
d,e,f=47,75.50,"bruce"

# %%
print(f)
# Out:
# bruce

# %%
del(var1)

# %%
print(var1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\DS WorkFlow\Data Is Good Class Files\Batches\2023-Classes\19th Nov Batch\Class 12.03.2023 -python introduction.ipynb Cell 18 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/DS%20WorkFlow/Data%20Is%20Good%20Class%20Files/Batches/2023-Classes/19th%20Nov%20Batch/Class%2012.03.2023%20-python%20introduction.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> print(var1)
#
# NameError: name 'var1' is not defined

# %%
#strings
name = "Leo Messi"

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(len(name))
# Out:
# 9

# %%
print(name[3])

# %%
print(name[-6])

# %%
name[0:9:2]
# Out:
# 'LoMsi'
