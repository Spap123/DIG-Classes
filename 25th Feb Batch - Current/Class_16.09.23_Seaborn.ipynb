# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ilpd = pd.read_csv("ILPD.csv")

# %%
sns.relplot(x = "DB" , y = "Gender" ,hue = "Sgpt", data = ilpd)
plt.show()

# %%
flights.head(20)
# Out:
#     year month  passengers
# 0   1949   Jan         112
# 1   1949   Feb         118
# 2   1949   Mar         132
# 3   1949   Apr         129
# 4   1949   May         121
# 5   1949   Jun         135
# 6   1949   Jul         148
# 7   1949   Aug         148
# 8   1949   Sep         136
# 9   1949   Oct         119
# 10  1949   Nov         104
# 11  1949   Dec         118
# 12  1950   Jan         115
# 13  1950   Feb         126
# 14  1950   Mar         141
# 15  1950   Apr         135
# 16  1950   May         125
# 17  1950   Jun         149
# 18  1950   Jul         170
# 19  1950   Aug         170

# %%
flights['year'].value_counts()
# Out:
# 1949    12
# 1950    12
# 1951    12
# 1952    12
# 1953    12
# 1954    12
# 1955    12
# 1956    12
# 1957    12
# 1958    12
# 1959    12
# 1960    12
# Name: year, dtype: int64

# %%
flights.isnull().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %%
sns.relplot(x = "passengers" , y = "month" ,hue = "year", data = flights)
plt.show()

# %%
iris = sns.load_dataset("iris")
tips = sns.load_dataset("tips")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
brain_networks= sns.load_dataset("brain_networks")

# %%
brain_networks
# Out:
#     network                    1                  1.1                   2  \
# 0      node                    1                    1                   1
# 1      hemi                   lh                   rh                  lh
# 2       NaN                  NaN                  NaN                 NaN
# 3         0    56.05574417114258    92.03103637695312   3.391575574874878
# 4         1     55.5472526550293     43.6900749206543  -65.49598693847656
# ..      ...                  ...                  ...                 ...
# 918     915  -7.4295125007629395    -4.81321907043457  -3.670536518096924
# 919     916   -33.55413818359375   -38.60562133789063  -25.66480255126953
# 920     917   -78.53956604003906   -74.19718933105469  -54.04159545898438
# 921     918  -103.23582458496094    -98.7442855834961  -40.10954284667969
# 922     919   -36.28886795043945  -10.762069702148438  -30.35626220703125
#
#                      2.1                    3                  3.1  \
# 0                      1                    1                    1
# 1                     rh                   lh                   rh
# 2                    NaN                  NaN                  NaN
# 3      38.65968322753906   26.203819274902344   -49.71556854248047
# 4    -13.974522590637207   -28.27496337890625   -39.05012893676758
# ..                   ...                  ...                  ...
# 918   1.4422610998153689    -19.6804313659668  -29.109355926513672
# 919  -30.252351760864254   5.5627851486206055   20.182186126708984
# 920   -39.97029113769531  -14.277058601379395  -30.606460571289066
# 921   -44.90773391723633   12.109148025512695   1.6213401556015017
# 922   -23.31950378417969   14.252187728881836   -27.55986022949219
#
#                        4                  4.1                     5  ...  \
# 0                      1                    1                     1  ...
# 1                     lh                   rh                    lh  ...
# 2                    NaN                  NaN                   NaN  ...
# 3       47.4610366821289   26.746612548828125   -35.898860931396484  ...
# 4    -1.2106596231460571  -19.012897491455078    19.568010330200195  ...
# ..                   ...                  ...                   ...  ...
# 918  -3.3765623569488525      -8.764892578125  0.017911728471517563  ...
# 919    17.91124725341797    24.65358161926269    -32.93561172485352  ...
# 920    60.62852096557617    62.02702331542969    -32.80055618286133  ...
# 921   33.765560150146484    55.35607147216797   -14.330512046813965  ...
# 922   17.279512405395508  -19.060152053833008     26.55877685546875  ...
#
#                    16.5                16.6                 16.7  \
# 0                     3                   4                    4
# 1                    rh                  lh                   rh
# 2                   NaN                 NaN                  NaN
# 3    0.6079040169715881  -70.27054595947266    77.36577606201172
# 4     57.49507141113281  -76.39321899414062   127.26136016845705
# ..                  ...                 ...                  ...
# 918   58.28579330444336   68.55741119384766    22.83304786682129
# 919   59.86481857299805   23.00457763671875   7.6574625968933105
# 920   68.76786804199219   49.66401672363281    64.55149841308594
# 921   103.1552505493164  106.45484924316406     9.04682731628418
# 922   102.0863037109375   80.05113983154297  -2.6426103115081787
#
#                       17                17.1                 17.2  \
# 0                      1                   1                    2
# 1                     lh                  rh                   lh
# 2                    NaN                 NaN                  NaN
# 3     -21.73455047607422  1.0282527208328247   7.7917842864990225
# 4    -13.035799026489258    46.3818244934082  -15.752449989318848
# ..                   ...                 ...                  ...
# 918    76.17948913574219    51.9346694946289   -6.614512920379639
# 919    50.96239852905274  13.696922302246096    63.50361633300781
# 920    43.80074691772461   8.144479751586914    47.28145980834961
# 921    46.67441940307617   40.95479583740234   0.8771800398826599
# 922  -12.229619979858398  -6.596726417541504   17.665163040161133
#
#                    17.3                 17.4                17.5  \
# 0                     2                    3                   3
# 1                    rh                   lh                  rh
# 2                   NaN                  NaN                 NaN
# 3     68.90372467041016  -10.520872116088867  120.49046325683594
# 4     31.00033187866211  -39.607521057128906   24.76401138305664
# ..                  ...                  ...                 ...
# 918  -6.690762042999268   22.893030166625977   48.27437973022461
# 919   57.40117645263672    24.97454833984375   51.97215270996094
# 920   70.49964904785156    66.99440002441406   81.53924560546875
# 921   37.57715225219727   20.517745971679688   3.124434232711792
# 922  16.153173446655273    8.300398826599121  33.687530517578125
#
#                     17.6
# 0                      4
# 1                     lh
# 2                    NaN
# 3    -39.686431884765625
# 4      -36.7710075378418
# ..                   ...
# 918    76.22845458984375
# 919    64.53878784179689
# 920    64.96977233886719
# 921    56.71838760375977
# 922   17.960655212402344
#
# [923 rows x 63 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x = "time" ,y = "tip" , data = tips , kind = 'line')
plt.show()

# %%
sns.catplot(x = "day" , y = "total_bill" , data = tips)
plt.show()

# %%
sns.catplot(x = "day" , y = "total_bill",kind= "boxen" , data = tips)
plt.show()

# %%
sns.catplot(x = "day" , y = "total_bill",kind= "violin" , data = tips)
plt.show()

# %%
c = np.random.normal(size = 100)

# %%
print(c)
# Out:
# [ 0.55137215 -1.04806537 -0.57173643 -0.66645741  1.53498497 -0.12056111
#   0.31227427  1.14830277  1.6001048  -0.43700622 -0.64934621  0.0463738
#  -0.99632476  0.43368624  0.29203118 -1.49011422 -1.29877824 -0.61673634
#   0.17470216  0.6133039   1.9101666  -1.39871538  1.32225542 -0.7201066
#  -1.30338712  0.82682819  0.0232313  -0.24995833 -0.90556615  0.92234077
#  -2.73246671 -0.42476979 -0.58396614  0.93296389  0.29104096 -0.2728532
#   0.17525231 -0.62401963 -1.19510422 -1.64325144  0.55024819  0.96929278
#   0.99975402  0.7021647  -2.62546917 -0.19133095 -0.63283582  0.43355713
#  -0.39046107  0.50807424  0.60726589 -0.53200152 -2.89996417  0.57617141
#  -0.07670272 -0.36344268  1.59632     2.1650596   0.83146034 -0.18335793
#   0.45247076  0.19834126  0.55061093  1.43377699  1.11863637 -1.59935913
#   0.37290525  0.0847401  -0.07978003  0.9768373   0.89318308  0.47494824
#  -1.86114106  1.03706822 -0.07140503 -1.03435378  0.91087098  0.66757945
#  -0.92601939 -0.97484731  0.35769613 -0.66304174 -1.35125877  0.55319599
#  -1.20227035 -1.51313908  1.76247448  0.78915524  0.71051847  1.42607172
#  -0.87915239  0.46164045 -0.34647002 -0.00618539 -0.65533528  0.2290895
#   0.07741959 -0.51502152 -1.90863002  0.30484897]

# %%
sns.distplot(c)
plt.show()
# Out:
# C:\Users\sengu\AppData\Local\Temp\ipykernel_3736\124608837.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris , hue = 'species',height = 2)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pct'] = (100*tips['tip'])/tips['total_bill']

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size    tip_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765

# %%
grid = sns.FacetGrid(tips , row = "sex" , col = "time")
grid.map(plt.hist,"tip_pct",bins = np.linspace(0,40,15))
