# %%
print('hello world')
# Out:
# hello world

# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\DS WorkFlow\Datasets\crime.csv")

# %%
df.tail(4)
# Out:
#     Year  Population  Violent crime total  \
# 51  2011   311587816              1206031
# 52  2012   313873685              1217067
# 53  2013   316497531              1199684
# 54  2014   318857056              1197987
#
#     Murder and nonnegligent Manslaughter  Legacy rape /1  Revised rape /2  \
# 51                                 14661           84175              NaN
# 52                                 14866           85141              NaN
# 53                                 14319           82109         113695.0
# 54                                 14249           84041         116645.0
#
#     Robbery  Aggravated assault  Property crime total  Burglary  ...  \
# 51   354772              752423               9052743   2185140  ...
# 52   355051              762009               9001992   2109932  ...
# 53   345095              726575               8650761   1931835  ...
# 54   325802              741291               8277829   1729806  ...
#
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Population', 'Violent crime total',
#        'Murder and nonnegligent Manslaughter', 'Legacy rape /1',
#        'Revised rape /2', 'Robbery', 'Aggravated assault',
#        'Property crime total', 'Burglary', 'Larceny-theft',
#        'Motor vehicle theft', 'Violent Crime rate',
#        'Murder and nonnegligent manslaughter rate', 'Legacy rape rate /1',
#        'Revised rape rate /2', 'Robbery rate', 'Aggravated assault rate',
#        'Property crime rate', 'Burglary rate', 'Larceny-theft rate',
#        'Motor vehicle theft rate'],
#       dtype='object')

# %%
df[['Year','Population']].describe()
#Pandas Series - []
#Pandas Dataframe - [[]]
# Out:
#              Year    Population
# count    55.00000  5.500000e+01
# mean   1987.00000  2.460985e+08
# std      16.02082  4.165900e+07
# min    1960.00000  1.793232e+08
# 25%    1973.50000  2.106215e+08
# 50%    1987.00000  2.422889e+08
# 75%    2000.50000  2.833697e+08
# max    2014.00000  3.188571e+08

# %%
df['Murder and nonnegligent manslaughter rate'].value_counts()
# Out:
# Murder and nonnegligent manslaughter rate
# 5.6     4
# 9.8     4
# 5.7     3
# 9.0     3
# 5.1     2
# 9.4     2
# 4.7     2
# 5.5     2
# 8.3     2
# 4.8     2
# 8.7     2
# 4.5     2
# 8.6     2
# 7.9     2
# 4.6     2
# 7.4     1
# 5.0     1
# 5.4     1
# 5.8     1
# 4.9     1
# 6.2     1
# 6.3     1
# 6.8     1
# 8.2     1
# 9.6     1
# 9.5     1
# 9.3     1
# 8.5     1
# 8.0     1
# 6.9     1
# 7.3     1
# 10.2    1
# 8.8     1
# 9.1     1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Year  Population  Violent crime total  \
# 0  1960   179323175               288460
# 1  1961   182992000               289390
# 2  1962   185771000               301510
# 3  1963   188483000               316970
# 4  1964   191141000               364220
#
#    Murder and nonnegligent Manslaughter  Legacy rape /1  Revised rape /2  \
# 0                                  9110           17190              NaN
# 1                                  8740           17220              NaN
# 2                                  8530           17550              NaN
# 3                                  8640           17650              NaN
# 4                                  9360           21420              NaN
#
#    Robbery  Aggravated assault  Property crime total  Burglary  ...  \
# 0   107840              154320               3095700    912100  ...
# 1   106670              156760               3198600    949600  ...
# ...

# %%
data = {
    'A':[1,2,3],
    'B':[4,5,6],
    'C':[7,8,9]
}
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.set_index('A',inplace=True)

# %%
df.head()
# Out:
#    B  C
# A
# 1  4  7
# 2  5  8
# 3  6  9

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.rename(
    index={0:'zero',1:'one',2:'two',3:'three'},
    columns={'A':'Alpha','B':'Beta','C':'Charlie'},inplace=True
)

# %%
df.head()
# Out:
#       Alpha  Beta  Charlie
# zero      1     4        7
# one       2     5        8
# two       3     6        9

# %%
df1 = pd.read_csv(r"D:\DS WorkFlow\Datasets\crime.csv")

# %%
df1.columns
# Out:
# Index(['Year', 'Population', 'Violent crime total',
#        'Murder and nonnegligent Manslaughter', 'Legacy rape /1',
#        'Revised rape /2', 'Robbery', 'Aggravated assault',
#        'Property crime total', 'Burglary', 'Larceny-theft',
#        'Motor vehicle theft', 'Violent Crime rate',
#        'Murder and nonnegligent manslaughter rate', 'Legacy rape rate /1',
#        'Revised rape rate /2', 'Robbery rate', 'Aggravated assault rate',
#        'Property crime rate', 'Burglary rate', 'Larceny-theft rate',
#        'Motor vehicle theft rate'],
#       dtype='object')

# %%
# nsmallest , nlargest
df1['Robbery rate'].nlargest()
# Out:
# 31    272.7
# 32    263.7
# 21    258.4
# 30    256.3
# 33    256.0
# Name: Robbery rate, dtype: float64

# %%
df1
# Out:
#     Year  Population  Violent crime total  \
# 0   1960   179323175               288460
# 1   1961   182992000               289390
# 2   1962   185771000               301510
# 3   1963   188483000               316970
# 4   1964   191141000               364220
# 5   1965   193526000               387390
# 6   1966   195576000               430180
# 7   1967   197457000               499930
# 8   1968   199399000               595010
# 9   1969   201385000               661870
# 10  1970   203235298               738820
# 11  1971   206212000               816500
# 12  1972   208230000               834900
# 13  1973   209851000               875910
# 14  1974   211392000               974720
# 15  1975   213124000              1039710
# 16  1976   214659000              1004210
# 17  1977   216332000              1029580
# 18  1978   218059000              1085550
# 19  1979   220099000              1208030
# 20  1980   225349264              1344520
# ...

# %%
df1['Robbery rate'].dtype
# Out:
# dtype('float64')

# %%
# where method
pd.set_option('display.max_columns',None)
where_result = df1.where(df1['Robbery rate']>100)
where_result.head(10)
# Out:
#      Year   Population  Violent crime total  \
# 0     NaN          NaN                  NaN
# 1     NaN          NaN                  NaN
# 2     NaN          NaN                  NaN
# 3     NaN          NaN                  NaN
# 4     NaN          NaN                  NaN
# 5     NaN          NaN                  NaN
# 6     NaN          NaN                  NaN
# 7  1967.0  197457000.0             499930.0
# 8  1968.0  199399000.0             595010.0
# 9  1969.0  201385000.0             661870.0
#
#    Murder and nonnegligent Manslaughter  Legacy rape /1  Revised rape /2  \
# 0                                   NaN             NaN              NaN
# 1                                   NaN             NaN              NaN
# 2                                   NaN             NaN              NaN
# 3                                   NaN             NaN              NaN
# 4                                   NaN             NaN              NaN
# ...

# %%
#query Method
query_result = df1.query('Year > 100')
query_result
# Out:
#     Year  Population  Violent crime total  \
# 0   1960   179323175               288460
# 1   1961   182992000               289390
# 2   1962   185771000               301510
# 3   1963   188483000               316970
# 4   1964   191141000               364220
# 5   1965   193526000               387390
# 6   1966   195576000               430180
# 7   1967   197457000               499930
# 8   1968   199399000               595010
# 9   1969   201385000               661870
# 10  1970   203235298               738820
# 11  1971   206212000               816500
# 12  1972   208230000               834900
# 13  1973   209851000               875910
# 14  1974   211392000               974720
# 15  1975   213124000              1039710
# 16  1976   214659000              1004210
# 17  1977   216332000              1029580
# 18  1978   218059000              1085550
# 19  1979   220099000              1208030
# 20  1980   225349264              1344520
# ...

# %%
df2 = (df1.query('Year > 1980')).copy()
df2.head()
# Out:
#     Year  Population  Violent crime total  \
# 21  1981   229465714              1361820
# 22  1982   231664458              1322390
# 23  1983   233791994              1258087
# 24  1984   235824902              1273282
# 25  1985   237923795              1327767
#
#     Murder and nonnegligent Manslaughter  Legacy rape /1  Revised rape /2  \
# 21                                 22520           82500              NaN
# 22                                 21010           78770              NaN
# 23                                 19308           78918              NaN
# 24                                 18692           84233              NaN
# 25                                 18976           87671              NaN
#
#     Robbery  Aggravated assault  Property crime total  Burglary  \
# 21   592910              663900              12061900   3779700
# 22   553130              669480              11652000   3447100
# 23   506567              653294              10850543   3129851
# ...

# %%
df_columns = list(df1.columns)

# %%
df_columns
# Out:
# ['Year',
#  'Population',
#  'Violent crime total',
#  'Murder and nonnegligent Manslaughter',
#  'Legacy rape /1',
#  'Revised rape /2',
#  'Robbery',
#  'Aggravated assault',
#  'Property crime total',
#  'Burglary',
#  'Larceny-theft',
#  'Motor vehicle theft',
#  'Violent Crime rate',
#  'Murder and nonnegligent manslaughter rate',
#  'Legacy rape rate /1',
#  'Revised rape rate /2',
#  'Robbery rate',
#  'Aggravated assault rate',
#  'Property crime rate',
#  'Burglary rate',
#  'Larceny-theft rate',
#  'Motor vehicle theft rate']

# %%
print(df1.median())
# Out:
# Year                                         1.987000e+03
# Population                                   2.422889e+08
# Violent crime total                          1.322390e+06
# Murder and nonnegligent Manslaughter         1.730900e+04
# Legacy rape /1                               8.423300e+04
# Revised rape /2                              1.151700e+05
# Robbery                                      4.235570e+05
# Aggravated assault                           7.412910e+05
# Property crime total                         1.018258e+07
# Burglary                                     2.332735e+06
# Larceny-theft                                6.591874e+06
# Motor vehicle theft                          1.032165e+06
# Violent Crime rate                           4.759000e+02
# Murder and nonnegligent manslaughter rate    7.300000e+00
# Legacy rape rate /1                          3.160000e+01
# Revised rape rate /2                         3.625000e+01
# ...

# %%
# group by 
data = {
    'Name':['John','Alice','Bob','Alice','John'],
    'Age':[30,25,35,25,20],
    'Salary':[30000,24000,19000,18000,35000]
}
df = pd.DataFrame(data)
df.head()
# Out:
#     Name  Age  Salary
# 0   John   30   30000
# 1  Alice   25   24000
# 2    Bob   35   19000
# 3  Alice   25   18000
# 4   John   20   35000

# %%
grouped = df.groupby('Name').mean()
grouped
# Out:
#         Age   Salary
# Name
# Alice  25.0  21000.0
# Bob    35.0  19000.0
# John   25.0  32500.0
