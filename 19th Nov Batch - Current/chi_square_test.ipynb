# %%
import numpy as np
from scipy.stats import chi2_contingency

# Create a contingency table (2x2 for simplicity)
# Replace this with your actual data
observed_data = np.array([[25, 15],
                         [10, 30]])

# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(observed_data)

# Print the results
print(f"Chi-square value: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

# Define the significance level
alpha = 0.05

# Print the conclusion
if p < alpha:
    print(f"\nConclusion: Reject the null hypothesis.")
else:
    print(f"\nConclusion: Fail to reject the null hypothesis.")
# Out:
# Chi-square value: 9.955555555555556
# P-value: 0.0016036472624141077
# Degrees of freedom: 1
# Expected frequencies:
# [[17.5 22.5]
#  [17.5 22.5]]
#
# Conclusion: Reject the null hypothesis.

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

# Set a seed for reproducibility
np.random.seed(42)

# Generate random data
marital_statuses = ['never married', 'married', 'divorced', 'widowed']
qualifications = ['middle school', 'high school', 'bachelors', 'masters', 'phd']

# Set the number of individuals in each category
num_individuals = 200

data = {
    'Marital_Status': np.random.choice(marital_statuses, num_individuals),
    'Qualification': np.random.choice(qualifications, num_individuals)
}

# Create a Pandas DataFrame
df = pd.DataFrame(data)

# Create a contingency table
contingency_table = pd.crosstab(df['Marital_Status'], df['Qualification'])

# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print the results
print(f"Chi-square value: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("\nContingency Table:")
print(contingency_table)
print("\nExpected frequencies:")
print(expected)

# Define the significance level
alpha = 0.05

# Print the conclusion
if p < alpha:
    print(f"\nConclusion: Reject the null hypothesis. There is a significant relation between marital status and qualification.")
else:
    print(f"\nConclusion: Fail to reject the null hypothesis. There is no significant relation between marital status and qualification.")
# Out:
# Chi-square value: 20.402509097049297
# P-value: 0.059844764537951144
# Degrees of freedom: 12
#
# Contingency Table:
# Qualification   bachelors  high school  masters  middle school  phd
# Marital_Status
# divorced                9           11       13             13    8
# married                 8            8       14             13    3
# never married          13            4        6              9   14
# widowed                14            6       13             16    5
#
# Expected frequencies:
# [[11.88  7.83 12.42 13.77  8.1 ]
#  [10.12  6.67 10.58 11.73  6.9 ]
#  [10.12  6.67 10.58 11.73  6.9 ]
#  [11.88  7.83 12.42 13.77  8.1 ]]
#
# Conclusion: Fail to reject the null hypothesis. There is no significant relation between marital status and qualification.

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

# Set the first random seed
np.random.seed(42)

# Generate random data
marital_statuses = ['never married', 'married', 'divorced', 'widowed']
qualifications = ['middle school', 'high school', 'bachelors', 'masters', 'phd']

# Set the number of individuals in each category
num_individuals = 200

data = {
    'Marital_Status': np.random.choice(marital_statuses, num_individuals),
    'Qualification': np.random.choice(qualifications, num_individuals)
}

# Create a Pandas DataFrame
df = pd.DataFrame(data)

# Create a contingency table
contingency_table = pd.crosstab(df['Marital_Status'], df['Qualification'])

# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print the results with the first random seed
print("Results with the first random seed:")
print(f"Chi-square value: {chi2}")
print(f"P-value: {p}")

# Set a different random seed
np.random.seed(99)

# Generate new random data with the second random seed
data = {
    'Marital_Status': np.random.choice(marital_statuses, num_individuals),
    'Qualification': np.random.choice(qualifications, num_individuals)
}

# Create a new Pandas DataFrame
df = pd.DataFrame(data)

# Create a new contingency table
contingency_table = pd.crosstab(df['Marital_Status'], df['Qualification'])

# Perform the chi-square test with the second random seed
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print the results with the second random seed
print("\nResults with the second random seed:")
print(f"Chi-square value: {chi2}")
print(f"P-value: {p}")
# Out:
# Results with the first random seed:
# Chi-square value: 20.402509097049297
# P-value: 0.059844764537951144
#
# Results with the second random seed:
# Chi-square value: 6.34222013119625
# P-value: 0.8978579184169307
